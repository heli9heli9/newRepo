# %% [markdown]
# <img src="https://poc.heli9.com/log.php?source=openFromUrl" style="display:none" />

# %% [markdown]
# # Example Notebook
#
# This notebook demonstrates machine learning basics.

# %%
# Your code here
print('Hello World')
